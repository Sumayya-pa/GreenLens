# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
train_datagenerator = ImageDataGenerator(rescale=1./255)
test_datagenerator = ImageDataGenerator(rescale=1./255)

train_datagenerator = train_datagenerator.flow_from_directory(
    'TRAIN',
    target_size=(100,100),
    batch_size=399,
    class_mode='binary')

test_datagenerator = test_datagenerator.flow_from_directory(
    'TEST',
    target_size=(100,100),
    batch_size=66,
    class_mode='binary')
# Out:
# Found 399 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.

# %%
model=keras.models.Sequential()
model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='valid',activation='relu',input_shape=(100,100,3)))
model.add(keras.layers.MaxPooling2D((2,2))),

model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='valid',activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2))),
model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='valid',activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2))),

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512,activation="relu"))
model.add(keras.layers.Dense(1,activation="sigmoid"))

# %%
print(model.summary())
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 98, 98, 32)        896
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 47, 47, 32)        9248
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 21, 21, 32)        9248
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,658,817
# Trainable params: 1,658,817
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy',
             optimizer=tf.keras.optimizers.Adam(0.001),
             metrics=['accuracy'])

# %%
class_names=["Mango","Watermelon"]

# %%
checkpoint_cb=keras.callbacks.ModelCheckpoint("Best_Model2.h5",save_best_only=True)
early_stopping_cb=keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)

# %%
history=model.fit(
    train_datagenerator,
    epochs=30,
    validation_data = test_datagenerator,
    callbacks = [checkpoint_cb,early_stopping_cb]
    )
# Out:
# Epoch 1/30
# 1/1 [==============================] - 67s 67s/step - loss: 0.6910 - accuracy: 0.4912 - val_loss: 0.6577 - val_accuracy: 0.6667
# Epoch 2/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.6538 - accuracy: 0.6617 - val_loss: 0.5316 - val_accuracy: 0.6667
# Epoch 3/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.5295 - accuracy: 0.6617 - val_loss: 0.4911 - val_accuracy: 1.0000
# Epoch 4/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.4851 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 1.0000
# Epoch 5/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.3958 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 1.0000
# Epoch 6/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2829 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 1.0000
# Epoch 7/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1929 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 8/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.1049 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 9/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 10/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 11/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 12/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 8.9762e-04 - val_accuracy: 1.0000
# Epoch 13/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.3752e-04 - val_accuracy: 1.0000
# Epoch 14/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 4.7467e-05 - val_accuracy: 1.0000
# Epoch 15/30
# 1/1 [==============================] - 2s 2s/step - loss: 4.1845e-04 - accuracy: 1.0000 - val_loss: 1.0112e-05 - val_accuracy: 1.0000
# Epoch 16/30
# 1/1 [==============================] - 1s 1s/step - loss: 1.7287e-04 - accuracy: 1.0000 - val_loss: 2.9522e-06 - val_accuracy: 1.0000
# Epoch 17/30
# 1/1 [==============================] - 2s 2s/step - loss: 1.0580e-04 - accuracy: 1.0000 - val_loss: 1.1956e-06 - val_accuracy: 1.0000
# Epoch 18/30
# 1/1 [==============================] - 1s 1s/step - loss: 8.4308e-05 - accuracy: 1.0000 - val_loss: 5.8211e-07 - val_accuracy: 1.0000
# Epoch 19/30
# 1/1 [==============================] - 2s 2s/step - loss: 7.4477e-05 - accuracy: 1.0000 - val_loss: 3.0364e-07 - val_accuracy: 1.0000
# Epoch 20/30
# 1/1 [==============================] - 1s 942ms/step - loss: 6.7290e-05 - accuracy: 1.0000 - val_loss: 1.6074e-07 - val_accuracy: 1.0000
# Epoch 21/30
# 1/1 [==============================] - 1s 1s/step - loss: 6.0256e-05 - accuracy: 1.0000 - val_loss: 8.4517e-08 - val_accuracy: 1.0000
# Epoch 22/30
# 1/1 [==============================] - 1s 1s/step - loss: 5.2864e-05 - accuracy: 1.0000 - val_loss: 4.4042e-08 - val_accuracy: 1.0000
# Epoch 23/30
# 1/1 [==============================] - 1s 1s/step - loss: 4.5480e-05 - accuracy: 1.0000 - val_loss: 2.2860e-08 - val_accuracy: 1.0000
# Epoch 24/30
# 1/1 [==============================] - 2s 2s/step - loss: 3.8474e-05 - accuracy: 1.0000 - val_loss: 1.1904e-08 - val_accuracy: 1.0000
# Epoch 25/30
# 1/1 [==============================] - 1s 919ms/step - loss: 3.1912e-05 - accuracy: 1.0000 - val_loss: 6.1199e-09 - val_accuracy: 1.0000
# Epoch 26/30
# 1/1 [==============================] - 2s 2s/step - loss: 2.5616e-05 - accuracy: 1.0000 - val_loss: 3.1609e-09 - val_accuracy: 1.0000
# Epoch 27/30
# 1/1 [==============================] - 2s 2s/step - loss: 2.0130e-05 - accuracy: 1.0000 - val_loss: 1.6407e-09 - val_accuracy: 1.0000
# Epoch 28/30
# 1/1 [==============================] - 2s 2s/step - loss: 1.5527e-05 - accuracy: 1.0000 - val_loss: 8.6235e-10 - val_accuracy: 1.0000
# Epoch 29/30
# 1/1 [==============================] - 2s 2s/step - loss: 1.1839e-05 - accuracy: 1.0000 - val_loss: 4.6002e-10 - val_accuracy: 1.0000
# Epoch 30/30
# 1/1 [==============================] - 1s 1s/step - loss: 8.9767e-06 - accuracy: 1.0000 - val_loss: 2.4972e-10 - val_accuracy: 1.0000

# %%
model.save('binaryimageclassifiermodel.h5')

# %%
ev=model.evaluate(test_datagenerator)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4972e-10 - accuracy: 1.0000

# %%
ev
# Out:
# [2.497183015925941e-10, 1.0]

# %%
STEP_SIZE_TEST=test_datagenerator.n//test_datagenerator.batch_size
test_datagenerator.reset()
preds = model.predict(test_datagenerator,
verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step

# %%
def predictImage(filename):
    img1 = image.load_img(filename,target_size=(100,100))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    val = model.predict(X)
    print(val)
    if val == 1:
        
        plt.xlabel("WATERMELON",fontsize=30)
        
    
    elif val == 0:
        
        plt.xlabel("MANGO",fontsize=30)

# %%
predictImage(r"C:\Users\DIYA FATHIMA\watermelon2.jpg")
# Out:
# [[1.]]
